# %%
datasets = [
    { "file_name": "DimArtist" },
    { "file_name": "DimDate" },
    { "file_name": "DimTrack" },
    { "file_name": "DimUsers" }
]

# %%
dbutils.jobs.taskValues.set(key="datasets", value=datasets)
